# %% [markdown]
# ### RunDate
# USed to get the source data. Batch Date in string format
# 20220101 -- Full load
# 20220102 -- Incremental
# 20220103 -- Incr

# %% [markdown]
# ### Job Control Table. Imp Table to logs the execution status of Pipeline. Columns under this table.
# ### Decide the load is incr or full load.
#
# Schema_name Table_name  max_timestamp rundate insert_dt
#
# ### Default Max time stamp while full loading.
#
# 19000101 12:00:00
